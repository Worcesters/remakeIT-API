# %%
import io, re, requests
import PIL, PIL.Image, PIL.ImageOps, PIL.ImageEnhance
from numpy import asarray

# %%
img_url = 'https://apod.nasa.gov/apod/image/2204/sunspotsleaningtowerofpisa.jpg'
download = requests.get(img_url)

# %%
type(download.content)
# Out:
# bytes

# %%
image = PIL.Image.open(io.BytesIO(download.content))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x1350 at 0x7FD4C9E98AF0>

# %%
data = asarray(image)
data
# Out:
# array([[[119,  77,  78],
#         [119,  77,  78],
#         [119,  77,  78],
#         ...,
#         [121,  77,  76],
#         [120,  76,  75],
#         [119,  75,  74]],
#
#        [[119,  77,  78],
#         [120,  78,  79],
#         [119,  77,  78],
#         ...,
#         [120,  76,  75],
#         [121,  77,  76],
#         [122,  78,  77]],
#
#        [[118,  76,  77],
#         [119,  77,  78],
#         [118,  76,  77],
#         ...,
#         [120,  76,  75],
#         [120,  76,  75],
#         [121,  77,  76]],
#
#        ...,
#
#        [[ 39,  32,  39],
#         [ 34,  27,  34],
#         [ 32,  25,  32],
#         ...,
#         [ 36,  31,  35],
#         [ 35,  30,  34],
#         [ 36,  31,  35]],
#
#        [[ 37,  30,  37],
#         [ 33,  26,  33],
#         [ 35,  28,  35],
#         ...,
#         [ 38,  33,  37],
#         [ 37,  32,  36],
#         [ 38,  33,  37]],
#
#        [[ 28,  21,  28],
#         [ 23,  16,  23],
#         [ 28,  23,  29],
# ...
